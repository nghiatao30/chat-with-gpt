# %% [markdown]
# #Efficient Conformer Demo
# A quick intro to using pretrained models and how to train/evaluate models.<br>
# repo: [https://github.com/burchim/EfficientConformer](https://github.com/burchim/EfficientConformer)

# %% [markdown]
# # Install

# %%
# !git clone https://github.com/burchim/EfficientConformer.git
# Out:
# fatal: destination path 'EfficientConformer' already exists and is not an empty directory.

# %%
import os
os.chdir('EfficientConformer/')

# %%
# !pip install -r requirements.txt
# Out:
# Exception:
# Traceback (most recent call last):
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 215, in main
#     status = self.run(options, args)
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\commands\install.py", line 272, in run
#     with self._build_session(options) as session:
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 69, in _build_session
#     if options.cache_dir else None
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\ntpath.py", line 75, in join
#     path = os.fspath(path)
# TypeError: expected str, bytes or os.PathLike object, not int
# Traceback (most recent call last):
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\khang\AppData\Local\Programs\Python\Python36\Scripts\pip.exe\__main__.py", line 9, in <module>
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\__init__.py", line 233, in main
#     return command.main(cmd_args)
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 251, in main
#     timeout=min(5, options.timeout)) as session:
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 69, in _build_session
#     if options.cache_dir else None
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\ntpath.py", line 75, in join
#     path = os.fspath(path)
# TypeError: expected str, bytes or os.PathLike object, not int

# %%
# !git clone --recursive https://github.com/parlance/ctcdecode.git
# !cd ctcdecode && pip install .
# Out:
# fatal: destination path 'ctcdecode' already exists and is not an empty directory.
# Exception:
# Traceback (most recent call last):
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 215, in main
#     status = self.run(options, args)
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\commands\install.py", line 272, in run
#     with self._build_session(options) as session:
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 69, in _build_session
#     if options.cache_dir else None
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\ntpath.py", line 75, in join
#     path = os.fspath(path)
# TypeError: expected str, bytes or os.PathLike object, not int
# Traceback (most recent call last):
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\khang\AppData\Local\Programs\Python\Python36\Scripts\pip.exe\__main__.py", line 9, in <module>
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\__init__.py", line 233, in main
#     return command.main(cmd_args)
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 251, in main
#     timeout=min(5, options.timeout)) as session:
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 69, in _build_session
#     if options.cache_dir else None
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\ntpath.py", line 75, in join
#     path = os.fspath(path)
# TypeError: expected str, bytes or os.PathLike object, not int

# %% [markdown]
# # Download pretrained models and tokenizer

# %%
# !pip install gdown
# Out:
# Exception:
# Traceback (most recent call last):
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 215, in main
#     status = self.run(options, args)
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\commands\install.py", line 272, in run
#     with self._build_session(options) as session:
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 69, in _build_session
#     if options.cache_dir else None
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\ntpath.py", line 75, in join
#     path = os.fspath(path)
# TypeError: expected str, bytes or os.PathLike object, not int
# Traceback (most recent call last):
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\khang\AppData\Local\Programs\Python\Python36\Scripts\pip.exe\__main__.py", line 9, in <module>
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\__init__.py", line 233, in main
#     return command.main(cmd_args)
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 251, in main
#     timeout=min(5, options.timeout)) as session:
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\site-packages\pip\basecommand.py", line 69, in _build_session
#     if options.cache_dir else None
#   File "c:\users\khang\appdata\local\programs\python\python36\lib\ntpath.py", line 75, in join
#     path = os.fspath(path)
# TypeError: expected str, bytes or os.PathLike object, not int

# %%
pretrained_models = {
    "EfficientConformerCTCSmall": "1MU49nbRONkOOGzvXHFDNfvWsyFmrrBam",
    "EfficientConformerCTCMedium": "1h5hRG9T_nErslm5eGgVzqx7dWDcOcGDB",
    "EfficientConformerCTCLarge": "1U4iBTKQogX4btE-S4rqCeeFZpj3gcweA"
}

# %%
# Select one of the official pretrained models
pretrained_model = "EfficientConformerCTCSmall"

# %%
import gdown

# Create model callback directory
if not os.path.exists(os.path.join("callbacks", pretrained_model)):
  os.mkdir(os.path.join("callbacks", pretrained_model))

# Download pretrained model checkpoint
gdown.download("https://drive.google.com/uc?id=" + pretrained_models[pretrained_model], os.path.join("callbacks", pretrained_model, "checkpoints_swa-equal-401-450.ckpt"), quiet=False)

# Create tokenizer directory
if not os.path.exists("datasets/LibriSpeech"):
  os.mkdir("datasets/LibriSpeech")

# Download pretrained model tokenizer
gdown.download("https://drive.google.com/uc?id=1hx2s4ZTDsnOFtx5_h5R_qZ3R6gEFafRx", "datasets/LibriSpeech/LibriSpeech_bpe_256.model", quiet=False)
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1MU49nbRONkOOGzvXHFDNfvWsyFmrrBam
# From (redirected): https://drive.google.com/uc?id=1MU49nbRONkOOGzvXHFDNfvWsyFmrrBam&confirm=t&uuid=6bebf184-3659-4ecc-90ea-924e9ffd8d20
# To: c:\CS337 Paper\talk-to-chatgpt\vits\EfficientConformer-master\EfficientConformer\callbacks\EfficientConformerCTCSmall\checkpoints_swa-equal-401-450.ckpt
#  13%|█▎        | 6.82M/53.8M [00:26<05:08, 152kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 8
#       5   os.mkdir(os.path.join("callbacks", pretrained_model))
#       7 # Download pretrained model checkpoint
# ----> 8 gdown.download("https://drive.google.com/uc?id=" + pretrained_models[pretrained_model], os.path.join("callbacks", pretrained_model, "checkpoints_swa-equal-401-450.ckpt"), quiet=False)
#      10 # Create tokenizer directory
#      11 if not os.path.exists("datasets/LibriSpeech"):
#
# File c:\Users\khang\AppData\Local\Programs\Python\Python310\lib\site-packages\gdown\download.py:334, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format)
#     332     pbar = tqdm.tqdm(total=total, unit="B", unit_scale=True)
#     333 t_start = time.time()
# --> 334 for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#     335     f.write(chunk)
#     336     if not quiet:
#
# File c:\Users\khang\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File c:\Users\khang\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File c:\Users\khang\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File c:\Users\khang\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\khang\AppData\Local\Programs\Python\Python310\lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File c:\Users\khang\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\khang\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\khang\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Test model on LibriSpeech samples

# %%
# Download LibriSPeech dev-clean subset
# !cd datasets && wget https://www.openslr.org/resources/12/dev-clean.tar.gz && tar xzf dev-clean.tar.gz

# Download LibriSPeech dev-other subset
# !cd datasets && wget https://www.openslr.org/resources/12/dev-other.tar.gz && tar xzf dev-other.tar.gz
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import json
import glob
import torch
import torchaudio
import IPython.display as ipd
from functions import create_model
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 6
#       4 import torchaudio
#       5 import IPython.display as ipd
# ----> 6 from functions import create_model
#       7 import matplotlib.pyplot as plt
#
# File c:\CS337 Paper\talk-to-chatgpt\vits\EfficientConformer-master\EfficientConformer\functions.py:19
#      16 import torch
#      18 # Models
# ---> 19 from models.transducer import Transducer
#      20 from models.model_ctc import ModelCTC, InterCTC
#      21 from models.lm import LanguageModel
#
# File c:\CS337 Paper\talk-to-chatgpt\vits\EfficientConformer-master\EfficientConformer\models\transducer.py:50
#      45 from models.losses import (
#      46     LossRNNT
#      47 )
#      49 # Ngram
# ---> 50 import kenlm
#      52 class Transducer(Model):
#      54     def __init__(self, encoder_params, decoder_params, joint_params, tokenizer_params, training_params, decoding_params, name):
#
# ModuleNotFoundError: No module named 'kenlm'

# %%
config_file = "configs/" + pretrained_model + ".json"

# Load model Config
with open(config_file) as json_config:
  config = json.load(json_config)

# PyTorch Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Create and Load pretrained model
model = create_model(config).to(device)
model.summary()
model.eval()
model.load(os.path.join("callbacks", pretrained_model, "checkpoints_swa-equal-401-450.ckpt"))
# Out:
# Running cells with 'c:\Users\khang\AppData\Local\Programs\Python\Python36\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/khang/AppData/Local/Programs/Python/Python36/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# Get audio files paths
audio_files = glob.glob("datasets/LibriSpeech/*/*/*/*.flac")
print(len(audio_files), "audio files")
# Out:
# Running cells with 'c:\Users\khang\AppData\Local\Programs\Python\Python36\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/khang/AppData/Local/Programs/Python/Python36/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# Random indices
indices = torch.randint(0, len(audio_files), size=(10,))

# Test model
for i in indices:

  # Load audio file
  audio, sr = torchaudio.load(audio_files[i])

  # Plot audio
  plt.title(audio_files[i].split("/")[-1])
  plt.plot(audio[0])
  plt.show()
  print()

  # Display
  ipd.display(ipd.Audio(audio, rate=sr))
  print()

  # Predict sentence
  prediction = model.gready_search_decoding(audio.to(device), x_len=torch.tensor([len(audio[0])], device=device))[0]
  print("model prediction:", prediction, '\n')

  for i in range(100):
    print('*', end='')
  print('\n')
# Out:
# Running cells with 'c:\Users\khang\AppData\Local\Programs\Python\Python36\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/khang/AppData/Local/Programs/Python/Python36/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Training
# Download the LibriSpeech dataset using:
#
# - `cd datasets && bash ./download_LibriSpeech.sh`
#
# Or download LibriSpeech train-clean 100h subset with:
#
# - `cd datasets && wget https://www.openslr.org/resources/12/train-clean-100.tar.gz && tar xzf datasets/train-clean-100.tar.gz`

# %%
# Download LibriSPeech train-clean-100 subset
# !cd datasets && wget https://www.openslr.org/resources/12/train-clean-100.tar.gz && tar xzf train-clean-100.tar.gz
# Out:
# Running cells with 'c:\Users\khang\AppData\Local\Programs\Python\Python36\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/khang/AppData/Local/Programs/Python/Python36/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Train an Efficient Conformer CTC Small model.<br>
# The `--prepare_dataset` flag will tokenize text sequences and save samples length before training/evaluation.<br>
# Use the `--create_tokenizer` flag if you need to create a new sentencepiece tokenizer.<br>
# Training mode is selected by default.

# %%
# Prepare dataset and train model
# !python main.py --config_file configs/EfficientConformerCTCSmall.json --prepare_dataset
# Out:
# Running cells with 'c:\Users\khang\AppData\Local\Programs\Python\Python36\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/khang/AppData/Local/Programs/Python/Python36/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Evaluation
# Proceed to a gready search evaluation.
# Use the `--mode` flag to select an evaluation mode:
#
# - `validation-clean` for evaluation on the LibriSpeech dev-clean validation set.
# - `validation-other` for evaluation on the LibriSpeech dev-other validation set.
# - `test-clean` for evaluation on the LibriSpeech test-clean test set.
# - `test-other` for evaluation on the LibriSpeech test-other test set.
# - `eval_time` to evaluate model inference time on the LibriSpeech dev-clean validation set.
#
# Select a model checkpoint to load for evaluation using the `--initial_epoch` flag.<br>
# For example, `--initial_epoch swa-equal-401-450` will load the pretrained checkpoints_swa-equal-401-450.ckpt file.

# %%
# !python main.py --config_file configs/EfficientConformerCTCSmall.json --mode validation-clean --initial_epoch swa-equal-401-450 --gready
# Out:
# Running cells with 'c:\Users\khang\AppData\Local\Programs\Python\Python36\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/khang/AppData/Local/Programs/Python/Python36/python.exe -m pip install ipykernel -U --user --force-reinstall'
